# %% [markdown]
# ## 라이브러리 import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn           as sb
import scipy.stats       as sp
import sympy             as sm

# %%
import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(777)

# %% [markdown]
# ## 데이터 불러오기

# %%
#몇차 데이터인지
testcase = "test5"

# %% [markdown]
# ## Preform-xy

# %%
for i in range (100):
    temp_data = pd.read_csv('./'+testcase+'/dp%d-preform-xy.csv'%(i+1),skiprows = 4, sep=',')
    
    if testcase[-1] == '3':
        s = "dp%d_preform_xy = temp_data[::-1]"%(i+1) ; exec(s)
    else:
        s = "dp%d_preform_xy = temp_data"%(i+1) ; exec(s)

# %%
dp1_preform_xy
# Out:
#      X [ m ]   Y [ m ]
# 0   0.000000 -0.037610
# 1   0.000965 -0.037610
# 2   0.001931 -0.037610
# 3   0.002889 -0.037610
# 4   0.003837 -0.037610
# 5   0.004780 -0.037610
# 6   0.005877 -0.037488
# 7   0.006921 -0.037129
# 8   0.007805 -0.036710
# 9   0.008696 -0.036287
# 10  0.009592 -0.035863
# 11  0.010487 -0.035439
# 12  0.011375 -0.035018
# 13  0.012259 -0.034599
# 14  0.013141 -0.034181
# 15  0.013967 -0.033742
# 16  0.014879 -0.033130
# 17  0.015958 -0.032188
# 18  0.017104 -0.030804
# 19  0.018132 -0.028891
# 20  0.019108 -0.026473
# 21  0.020151 -0.023892
# 22  0.021223 -0.021239
# 23  0.022297 -0.018580
# 24  0.023372 -0.015921
# 25  0.024446 -0.013261
# 26  0.025520 -0.010603
# 27  0.026589 -0.007958
# 28  0.027627 -0.005390
# 29  0.028520 -0.003178
# 30  0.029262 -0.001342
# 31  0.029732  0.000149
# 32  0.029941  0.001414
# 33  0.029990  0.002404
# 34  0.029990  0.003390

# %%
plt.figure(figsize = (5,6))
plt.grid(alpha = 0.5)
plt.title("dp1_preform_xy",fontsize = 16)
plt.xlabel('X [m]')
# plt.xlim(0,0.08)
plt.ylabel('Y [m]')
# plt.ylim(-0.35,0)
plt.plot(dp1_preform_xy.iloc[:,0],dp1_preform_xy.iloc[:,1])
# plt.scatter(dp1_preform_xy.iloc[:,0],dp1_preform_xy.iloc[:,1])
# plt.savefig("D:/testoneblow/pictures/"+testcase+"_preform_thick.jpg",bbox_inches = 'tight')

# %% [markdown]
# ### preform 길이

# %%
preform_Length = 0
for i in range(dp1_preform_xy.shape[0]-1):
    x_diff = dp1_preform_xy.iloc[i+1,0]-dp1_preform_xy.iloc[i,0]
    y_diff = dp1_preform_xy.iloc[i+1,1]-dp1_preform_xy.iloc[i,1]
    point_Length = np.sqrt(np.square(x_diff)+np.square(y_diff))
    preform_Length = preform_Length+point_Length
print(preform_Length)
# Out:
# 0.055840799766513995

# %%
preform_length_factor = []
for j in range(100):
    exec("temp_preform_xy = dp%d_preform_xy"%(j+1))
    preform_Length = 0
    for i in range(temp_preform_xy.shape[0]-1):
        x_diff = temp_preform_xy.iloc[i+1,0]-temp_preform_xy.iloc[i,0]
        y_diff = temp_preform_xy.iloc[i+1,1]-temp_preform_xy.iloc[i,1]
        point_Length = np.sqrt(np.square(x_diff)+np.square(y_diff))
        preform_Length = preform_Length+point_Length
    preform_length_factor = np.append(preform_length_factor,preform_Length)
preform_length_factor
# Out:
# array([0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408, 0.0558408,
#        0.0558408, 0.0558408, 0.0558408, 0.0558408])

# %% [markdown]
# ### preform 넓이

# %%
#구분구적법으로 면적 구하기
preform_area = 0
for i in range(dp1_preform_xy.shape[0]-1):
    height = np.abs(dp1_preform_xy.iloc[i+1,1]-dp1_preform_xy.iloc[i,1])
    width = np.abs(dp1_preform_xy.iloc[i+1,0]+dp1_preform_xy.iloc[i,0])/2
    area_ = height * width
    preform_area = preform_area + area_
print(preform_area)
# Out:
# 0.0009121829042897367

# %%
preform_area_factor = []
for j in range(100):
    exec("temp_preform_xy = dp%d_preform_xy"%(j+1))
    preform_area = 0
    for i in range(temp_preform_xy.shape[0]-1):
        height = np.abs(temp_preform_xy.iloc[i+1,1]-temp_preform_xy.iloc[i,1])
        width = np.abs(temp_preform_xy.iloc[i+1,0]+temp_preform_xy.iloc[i,0])/2
        area_ = height * width
        preform_area = preform_area + area_
    preform_area_factor = np.append(preform_area_factor,preform_area)
    
preform_area_factor
# Out:
# array([0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218,
#        0.00091218, 0.00091218, 0.00091218, 0.00091218, 0.00091218])

# %% [markdown]
# ### preform 부피

# %%
#구분구적법으로 면적 구하기
preform_volume = 0
for i in range(dp1_preform_xy.shape[0]-1):
    height = np.abs(dp1_preform_xy.iloc[i+1,1]-dp1_preform_xy.iloc[i,1])
    width = np.abs(dp1_preform_xy.iloc[i+1,0]+dp1_preform_xy.iloc[i,0])/2
    bottom_area = np.pi* np.square(width)
    volume_ = height * bottom_area
    
    preform_volume = preform_volume + volume_
print(preform_volume)
# Out:
# 6.810623745120074e-05

# %%
preform_volume_factor = []
for j in range(100):
    exec("temp_preform_xy = dp%d_preform_xy"%(j+1))
    preform_volume = 0
    for i in range(temp_preform_xy.shape[0]-1):
        height = np.abs(temp_preform_xy.iloc[i+1,1]-temp_preform_xy.iloc[i,1])
        width = np.abs(temp_preform_xy.iloc[i+1,0]+temp_preform_xy.iloc[i,0])/2
        
        bottom_area = np.pi* np.square(width)
        
        volume_ = height * bottom_area
        
        preform_volume = preform_volume + volume_
    preform_volume_factor = np.append(preform_volume_factor,preform_volume)
    
preform_volume_factor
# Out:
# array([6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05,
#        6.81062375e-05, 6.81062375e-05, 6.81062375e-05, 6.81062375e-05])

# %% [markdown]
# ### preform 가로세로 종횡비 = y_max / x_max

# %%
preform_xyratio_factor = []
for j in range(100):
    exec("temp_preform_xy = dp%d_preform_xy"%(j+1))
    x_max = np.max(np.abs(temp_preform_xy.iloc[:,0]))
    y_max = np.max(np.abs(temp_preform_xy.iloc[:,1]))
    xyratio = y_max/x_max
    preform_xyratio_factor = np.append(preform_xyratio_factor,xyratio)
preform_xyratio_factor
# Out:
# array([1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473,
#        1.25408473, 1.25408473, 1.25408473, 1.25408473, 1.25408473])

# %% [markdown]
# ## Blow-xy

# %%
for i in range (100):
    temp_data = pd.read_csv('./'+testcase+'/dp%d-blow-xy.csv'%(i+1),skiprows = 4, sep=',')
    
    if testcase[-1] == '3':
        s = "dp%d_blow_xy = temp_data[::-1]"%(i+1) ; exec(s)
    else:
        s = "dp%d_blow_xy = temp_data"%(i+1) ; exec(s)

# %% [markdown]
# ### blow 길이

# %%
blow_length_factor = []
for j in range(100):
    exec("temp_blow_xy = dp%d_blow_xy"%(j+1))
    blow_Length = 0
    for i in range(temp_blow_xy.shape[0]-1):
        x_diff = temp_blow_xy.iloc[i+1,0]-temp_blow_xy.iloc[i,0]
        y_diff = temp_blow_xy.iloc[i+1,1]-temp_blow_xy.iloc[i,1]
        point_Length = np.sqrt(np.square(x_diff)+np.square(y_diff))
        blow_Length = blow_Length+point_Length
    blow_length_factor = np.append(blow_length_factor,blow_Length)
blow_length_factor
# Out:
# array([0.12033605, 0.12037908, 0.12040799, 0.12030494, 0.12033091,
#        0.12035955, 0.12037299, 0.12044688, 0.1204727 , 0.12038435,
#        0.12049329, 0.12037823, 0.12028127, 0.12021999, 0.12035606,
#        0.12027112, 0.12029289, 0.12033528, 0.12040134, 0.12034638,
#        0.12036109, 0.12039118, 0.12036529, 0.12021972, 0.1202904 ,
#        0.1203545 , 0.12039598, 0.12033759, 0.12038817, 0.12041548,
#        0.12046657, 0.12033654, 0.12033881, 0.12041955, 0.12048482,
#        0.12039432, 0.12052963, 0.12048264, 0.1204017 , 0.12042785,
#        0.12042141, 0.12024842, 0.12036147, 0.12033252, 0.12046113,
#        0.12036178, 0.12033143, 0.12038822, 0.12042832, 0.12054118,
#        0.12025493, 0.12047228, 0.12051573, 0.1203084 , 0.12028226,
#        0.12045456, 0.12039158, 0.12030454, 0.12052586, 0.12050935,
#        0.12045589, 0.12042192, 0.12044315, 0.12032125, 0.12059353,
#        0.12054787, 0.12045365, 0.12040775, 0.12041955, 0.12037191,
#        0.12042488, 0.12051456, 0.12042289, 0.12037982, 0.12054765,
#        0.12040938, 0.1204665 , 0.12050051, 0.12052715, 0.12032831,
#        0.1203145 , 0.12045562, 0.1205073 , 0.12042291, 0.12056742,
#        0.1205242 , 0.12050093, 0.12047702, 0.12051017, 0.12057271,
#        0.12050118, 0.12040341, 0.12041299, 0.12054128, 0.12050358,
#        0.12052997, 0.12044872, 0.1206053 , 0.12048956, 0.12048851])

# %% [markdown]
# ### blow 넓이

# %%
blow_area_factor = []
for j in range(100):
    exec("temp_blow_xy = dp%d_blow_xy"%(j+1))
    print("dp%d blow area"%(j+1))
    print("\t")
    
    for k in range(temp_blow_xy.shape[0]):
        if temp_blow_xy.iloc[k+5,1]-temp_blow_xy.iloc[k+6,1]<0:
            cut_index = k+5
            print("cut_index = ",cut_index)
            break
    
    blow_area = 0
    for i in range(temp_blow_xy.shape[0]-cut_index-1):
        height = np.abs(temp_blow_xy.iloc[cut_index+i+1,1]-temp_blow_xy.iloc[cut_index+i,1])
        width = np.abs(temp_blow_xy.iloc[cut_index+i+1,0]+temp_blow_xy.iloc[cut_index+i,0])/2
        area_ = height * width
        blow_area = blow_area + area_
        
        
    null_area = 0
    for l in range(cut_index):
        height = np.abs(temp_blow_xy.iloc[l+1,1]-temp_blow_xy.iloc[l,1])
        width = np.abs(temp_blow_xy.iloc[l+1,0]+temp_blow_xy.iloc[l,0])/2
        area_ = height * width
        null_area = null_area + area_
    
    
    print("blow_area = ",blow_area)
    print("null_area = ",null_area)
    blow_area = blow_area - null_area
    print("final blow_area = ",blow_area)
    blow_area_factor = np.append(blow_area_factor,blow_area)
    print("--------------------------------\t")
# blow_area_factor
# Out:
# dp1 blow area
#
# cut_index =  12
# blow_area =  0.0031262287670137112
# null_area =  5.3334242189156074e-05
# final blow_area =  0.003072894524824555
# --------------------------------
# dp2 blow area
#
# cut_index =  11
# blow_area =  0.0031201898307380736
# null_area =  5.0695690566516515e-05
# final blow_area =  0.003069494140171557
# --------------------------------
# dp3 blow area
#
# cut_index =  11
# blow_area =  0.003123742249044087
# null_area =  5.3635273343773394e-05
# final blow_area =  0.003070106975700314
# --------------------------------
# dp4 blow area
#
# cut_index =  15
# blow_area =  0.003124455052880851
# null_area =  5.4086924965808276e-05
# final blow_area =  0.0030703681279150427
# --------------------------------
# dp5 blow area
#
# cut_index =  12
# blow_area =  0.003128841852164829
# null_area =  6.0068411826439224e-05
# final blow_area =  0.0030687734403383898
# --------------------------------
# dp6 blow area
#
# cut_index =  12
# blow_area =  0.003129045065973721
# null_area =  5.8259626278369794e-05
# final blow_area =  0.0030707854396953512
# --------------------------------
# dp7 blow area
#
# cut_index =  15
# blow_area =  0.0031314048618376355
# null_area =  5.850072028115548e-05
# final blow_area =  0.00307290414155648
# --------------------------------
# dp8 blow area
#
# cut_index =  13
# blow_area =  0.0031336850849756634
# null_area =  6.374660704654789e-05
# final blow_area =  0.0030699384779291155
# --------------------------------
# dp9 blow area
#
# cut_index =  12
# blow_area =  0.0031320266361401566
# null_area =  6.174144102317005e-05
# final blow_area =  0.0030702851951169867
# --------------------------------
# dp10 blow area
#
# cut_index =  12
# blow_area =  0.0031279671111655366
# null_area =  5.90099925669388e-05
# final blow_area =  0.0030689571185985977
# --------------------------------
# dp11 blow area
#
# cut_index =  12
# blow_area =  0.003130182287364748
# null_area =  5.98054814557545e-05
# final blow_area =  0.0030703768059089933
# --------------------------------
# dp12 blow area
#
# cut_index =  13
# blow_area =  0.0031244833066028876
# null_area =  5.397715744979139e-05
# final blow_area =  0.0030705061491530963
# --------------------------------
# dp13 blow area
#
# cut_index =  15
# blow_area =  0.003125671340547194
# null_area =  5.776365828812381e-05
# final blow_area =  0.0030679076822590703
# --------------------------------
# dp14 blow area
#
# cut_index =  11
# blow_area =  0.0031138849006809768
# null_area =  4.634984011168916e-05
# final blow_area =  0.0030675350605692876
# --------------------------------
# dp15 blow area
#
# cut_index =  13
# blow_area =  0.0031285664904097737
# null_area =  5.8856533749960835e-05
# final blow_area =  0.003069709956659813
# --------------------------------
# dp16 blow area
#
# cut_index =  12
# blow_area =  0.0031242821920158675
# null_area =  5.371304490123669e-05
# final blow_area =  0.003070569147114631
# --------------------------------
# dp17 blow area
#
# cut_index =  16
# blow_area =  0.003126229061597838
# null_area =  5.444620722900986e-05
# final blow_area =  0.003071782854368828
# --------------------------------
# dp18 blow area
#
# cut_index =  13
# blow_area =  0.0031250338606001733
# null_area =  5.305995555904615e-05
# final blow_area =  0.003071973905041127
# --------------------------------
# dp97 blow area
#
# cut_index =  17
# blow_area =  0.003126854484169772
# null_area =  5.5741003811736375e-05
# final blow_area =  0.0030711134803580358
# --------------------------------
# dp98 blow area
#
# cut_index =  13
# blow_area =  0.003131136781389933
# null_area =  5.692383181657414e-05
# final blow_area =  0.0030742129495733585
# --------------------------------
# dp99 blow area
#
# cut_index =  12
# blow_area =  0.0031319981271947105
# null_area =  6.002926070244814e-05
# final blow_area =  0.0030719688664922625
# --------------------------------
# dp100 blow area
#
# cut_index =  18
# blow_area =  0.0031305158848253306
# null_area =  5.85852913825532e-05
# final blow_area =  0.003071930593442777
# --------------------------------

# %%
blow_area_factor
# Out:
# array([0.00307289, 0.00306949, 0.00307011, 0.00307037, 0.00306877,
#        0.00307079, 0.0030729 , 0.00306994, 0.00307029, 0.00306896,
#        0.00307038, 0.00307051, 0.00306791, 0.00306754, 0.00306971,
#        0.00307057, 0.00307178, 0.00306814, 0.00307105, 0.00306938,
#        0.0030716 , 0.00307176, 0.00306811, 0.00306826, 0.00306948,
#        0.00307009, 0.00306903, 0.00307129, 0.00307082, 0.00307229,
#        0.00307196, 0.00307092, 0.0030713 , 0.00307103, 0.00307216,
#        0.00306995, 0.00307436, 0.0030719 , 0.00307065, 0.00307026,
#        0.00307159, 0.00306876, 0.00307012, 0.0030692 , 0.00307212,
#        0.00306883, 0.00307125, 0.00307132, 0.00307151, 0.00307127,
#        0.00306833, 0.00307197, 0.00307287, 0.00306869, 0.00306603,
#        0.00307318, 0.00306945, 0.00306826, 0.00307171, 0.00307346,
#        0.00307022, 0.00306954, 0.00307062, 0.00307053, 0.00307392,
#        0.00307276, 0.00306997, 0.00307024, 0.00307006, 0.00306974,
#        0.00307232, 0.0030729 , 0.00307057, 0.00307125, 0.00307315,
#        0.00307041, 0.00307179, 0.00307296, 0.00307349, 0.00307201,
#        0.00317492, 0.00307282, 0.00307239, 0.00307243, 0.00307254,
#        0.00307281, 0.00307154, 0.00307134, 0.00307158, 0.00307306,
#        0.00307311, 0.00307211, 0.00307195, 0.00307238, 0.00307355,
#        0.00307197, 0.00307111, 0.00307421, 0.00307197, 0.00307193])

# %% [markdown]
# ### blow 부피

# %%
blow_volume_factor = []
for j in range(100):
    exec("temp_blow_xy = dp%d_blow_xy"%(j+1))
    print("dp%d blow volume"%(j+1))
    print("\t")
    
    for k in range(temp_blow_xy.shape[0]):
        if temp_blow_xy.iloc[k+5,1]-temp_blow_xy.iloc[k+6,1]<0:
            cut_index = k+5
            print("cut_index = ",cut_index)
            break
    
    blow_volume = 0
    for i in range(temp_blow_xy.shape[0]-cut_index-1):
        height = np.abs(temp_blow_xy.iloc[cut_index+i+1,1]-temp_blow_xy.iloc[cut_index+i,1])
        width = np.abs(temp_blow_xy.iloc[cut_index+i+1,0]+temp_blow_xy.iloc[cut_index+i,0])/2
        
        bottom_area = np.pi* np.square(width)
        
        volume_ = height * bottom_area
        blow_volume = blow_volume + volume_
        
        
    null_volume = 0
    for l in range(cut_index):
        height = np.abs(temp_blow_xy.iloc[l+1,1]-temp_blow_xy.iloc[l,1])
        width = np.abs(temp_blow_xy.iloc[l+1,0]+temp_blow_xy.iloc[l,0])/2
        
        bottom_area = np.pi* np.square(width)

        volume_ = height * width
        null_volume = null_volume + volume_
    
    
    print("blow_volume = ",blow_volume)
    print("null_volume = ",null_volume)
    blow_volume = blow_volume - null_volume
    print("final blow_volume = ",blow_volume)
    blow_volume_factor = np.append(blow_volume_factor,blow_volume)
    print("--------------------------------\t")
# blow_volume_factor
# Out:
# dp1 blow volume
#
# cut_index =  12
# blow_volume =  0.0003774409083352341
# null_volume =  5.3334242189156074e-05
# final blow_volume =  0.000324106666146078
# --------------------------------
# dp2 blow volume
#
# cut_index =  11
# blow_volume =  0.0003764591535962857
# null_volume =  5.0695690566516515e-05
# final blow_volume =  0.00032576346302976917
# --------------------------------
# dp3 blow volume
#
# cut_index =  11
# blow_volume =  0.0003766164949193065
# null_volume =  5.3635273343773394e-05
# final blow_volume =  0.0003229812215755331
# --------------------------------
# dp4 blow volume
#
# cut_index =  15
# blow_volume =  0.0003766488579749077
# null_volume =  5.4086924965808276e-05
# final blow_volume =  0.0003225619330090994
# --------------------------------
# dp5 blow volume
#
# cut_index =  12
# blow_volume =  0.00037687044886603187
# null_volume =  6.0068411826439224e-05
# final blow_volume =  0.00031680203703959267
# --------------------------------
# dp6 blow volume
#
# cut_index =  12
# blow_volume =  0.0003772814839078886
# null_volume =  5.8259626278369794e-05
# final blow_volume =  0.00031902185762951884
# --------------------------------
# dp7 blow volume
#
# cut_index =  15
# blow_volume =  0.00037765377853754594
# null_volume =  5.850072028115548e-05
# final blow_volume =  0.00031915305825639046
# --------------------------------
# dp8 blow volume
#
# cut_index =  13
# blow_volume =  0.0003772824249883335
# null_volume =  6.374660704654789e-05
# final blow_volume =  0.0003135358179417856
# --------------------------------
# dp9 blow volume
#
# cut_index =  12
# blow_volume =  0.0003773294135737537
# null_volume =  6.174144102317005e-05
# final blow_volume =  0.00031558797255058367
# --------------------------------
# dp10 blow volume
#
# cut_index =  12
# blow_volume =  0.0003768186839800425
# null_volume =  5.90099925669388e-05
# final blow_volume =  0.0003178086914131037
# --------------------------------
# dp11 blow volume
#
# cut_index =  12
# blow_volume =  0.0003771816691180992
# null_volume =  5.98054814557545e-05
# final blow_volume =  0.00031737618766234467
# --------------------------------
# dp12 blow volume
#
# cut_index =  13
# blow_volume =  0.0003768050821128867
# null_volume =  5.397715744979139e-05
# final blow_volume =  0.0003228279246630953
# --------------------------------
# dp13 blow volume
#
# cut_index =  15
# blow_volume =  0.00037636446103422964
# null_volume =  5.776365828812381e-05
# final blow_volume =  0.00031860080274610585
# --------------------------------
# dp14 blow volume
#
# cut_index =  11
# blow_volume =  0.0003756829720078421
# null_volume =  4.634984011168916e-05
# final blow_volume =  0.000329333131896153
# --------------------------------
# dp15 blow volume
#
# cut_index =  13
# blow_volume =  0.0003769352367539218
# null_volume =  5.8856533749960835e-05
# final blow_volume =  0.000318078703003961
# --------------------------------
# dp16 blow volume
#
# cut_index =  12
# blow_volume =  0.00037696740652935865
# null_volume =  5.371304490123669e-05
# final blow_volume =  0.00032325436162812196
# --------------------------------
# dp17 blow volume
#
# cut_index =  16
# blow_volume =  0.00037707009725457177
# null_volume =  5.444620722900986e-05
# final blow_volume =  0.0003226238900255619
# --------------------------------
# dp18 blow volume
#
# cut_index =  14
# blow_volume =  0.00037618436827301056
# null_volume =  5.3724279063057665e-05
# final blow_volume =  0.0003224600892099529
# --------------------------------
# dp19 blow volume
#
# cut_index =  18
# blow_volume =  0.0003770287113392502
# null_volume =  5.821926078209799e-05
# final blow_volume =  0.0003188094505571522
# --------------------------------
# dp20 blow volume
#
# cut_index =  13
# blow_volume =  0.00037643180452404557
# null_volume =  5.193647311672847e-05
# final blow_volume =  0.0003244953314073171
# --------------------------------
# dp21 blow volume
#
# cut_index =  13
# blow_volume =  0.00037721305727293514
# null_volume =  5.6430095380841964e-05
# final blow_volume =  0.0003207829618920932
# --------------------------------
# dp22 blow volume
#
# cut_index =  16
# blow_volume =  0.0003772724175775769
# null_volume =  5.7705534437864654e-05
# final blow_volume =  0.00031956688313971226
# --------------------------------
# dp23 blow volume
#
# cut_index =  12
# blow_volume =  0.0003764838740383109
# null_volume =  5.7045920745943885e-05
# final blow_volume =  0.000319437953292367
# --------------------------------
# dp24 blow volume
#
# cut_index =  15
# blow_volume =  0.0003762916790481978
# null_volume =  5.496480824267647e-05
# final blow_volume =  0.0003213268708055213
# --------------------------------
# dp25 blow volume
#
# cut_index =  12
# blow_volume =  0.00037643549852227353
# null_volume =  4.990047053956328e-05
# final blow_volume =  0.00032653502798271026
# --------------------------------
# dp26 blow volume
#
# cut_index =  12
# blow_volume =  0.0003767345620938448
# null_volume =  5.629392549563697e-05
# final blow_volume =  0.00032044063659820787
# --------------------------------
# dp27 blow volume
#
# cut_index =  13
# blow_volume =  0.00037686261272391316
# null_volume =  6.046305842641107e-05
# final blow_volume =  0.0003163995542975021
# --------------------------------
# dp28 blow volume
#
# cut_index =  15
# blow_volume =  0.00037721229016168
# null_volume =  5.8403540011216424e-05
# final blow_volume =  0.00031880875015046357
# --------------------------------
# dp29 blow volume
#
# cut_index =  14
# blow_volume =  0.0003771188948590123
# null_volume =  5.96598839889648e-05
# final blow_volume =  0.0003174590108700475
# --------------------------------
# dp30 blow volume
#
# cut_index =  13
# blow_volume =  0.0003777399360115423
# null_volume =  6.10866483465118e-05
# final blow_volume =  0.0003166532876650305
# --------------------------------
# dp31 blow volume
#
# cut_index =  13
# blow_volume =  0.0003772628693435124
# null_volume =  5.641717728556203e-05
# final blow_volume =  0.0003208456920579504
# --------------------------------
# dp32 blow volume
#
# cut_index =  11
# blow_volume =  0.00037637889562406755
# null_volume =  4.679636964356569e-05
# final blow_volume =  0.00032958252598050186
# --------------------------------
# dp33 blow volume
#
# cut_index =  13
# blow_volume =  0.0003769306324914698
# null_volume =  5.362977947741363e-05
# final blow_volume =  0.00032330085301405614
# --------------------------------
# dp34 blow volume
#
# cut_index =  13
# blow_volume =  0.00037720549928030973
# null_volume =  5.797588090155359e-05
# final blow_volume =  0.00031922961837875616
# --------------------------------
# dp35 blow volume
#
# cut_index =  12
# blow_volume =  0.00037767305086276883
# null_volume =  6.106961395635756e-05
# final blow_volume =  0.00031660343690641127
# --------------------------------
# dp36 blow volume
#
# cut_index =  16
# blow_volume =  0.0003769256115778916
# null_volume =  5.874644529181988e-05
# final blow_volume =  0.0003181791662860717
# --------------------------------
# dp37 blow volume
#
# cut_index =  14
# blow_volume =  0.00037795869021236146
# null_volume =  5.8180253111924285e-05
# final blow_volume =  0.00031977843710043717
# --------------------------------
# dp38 blow volume
#
# cut_index =  12
# blow_volume =  0.00037761864571896254
# null_volume =  6.074345615804418e-05
# final blow_volume =  0.0003168751895609184
# --------------------------------
# dp39 blow volume
#
# cut_index =  13
# blow_volume =  0.00037719179947459815
# null_volume =  5.8922976819038426e-05
# final blow_volume =  0.00031826882265555974
# --------------------------------
# dp40 blow volume
#
# cut_index =  13
# blow_volume =  0.0003771265323937225
# null_volume =  6.0499739865193055e-05
# final blow_volume =  0.00031662679252852943
# --------------------------------
# dp41 blow volume
#
# cut_index =  16
# blow_volume =  0.0003771406023150923
# null_volume =  5.584362297629406e-05
# final blow_volume =  0.00032129697933879826
# --------------------------------
# dp42 blow volume
#
# cut_index =  17
# blow_volume =  0.00037657019253982773
# null_volume =  5.7758933823486784e-05
# final blow_volume =  0.00031881125871634095
# --------------------------------
# dp43 blow volume
#
# cut_index =  14
# blow_volume =  0.00037689512453574595
# null_volume =  5.5959407245032724e-05
# final blow_volume =  0.0003209357172907132
# --------------------------------
# dp44 blow volume
#
# cut_index =  14
# blow_volume =  0.0003765302372611574
# null_volume =  5.529033713184233e-05
# final blow_volume =  0.00032123990012931507
# --------------------------------
# dp45 blow volume
#
# cut_index =  13
# blow_volume =  0.0003770591791200917
# null_volume =  5.333849142096458e-05
# final blow_volume =  0.00032372068769912713
# --------------------------------
# dp46 blow volume
#
# cut_index =  12
# blow_volume =  0.00037669512068191306
# null_volume =  5.622883564741003e-05
# final blow_volume =  0.00032046628503450304
# --------------------------------
# dp47 blow volume
#
# cut_index =  13
# blow_volume =  0.00037685310848891844
# null_volume =  5.151149227762452e-05
# final blow_volume =  0.00032534161621129395
# --------------------------------
# dp48 blow volume
#
# cut_index =  14
# blow_volume =  0.0003773985240149739
# null_volume =  5.938207912176836e-05
# final blow_volume =  0.00031801644489320557
# --------------------------------
# dp49 blow volume
#
# cut_index =  13
# blow_volume =  0.00037717097430724206
# null_volume =  5.589208385806164e-05
# final blow_volume =  0.0003212788904491804
# --------------------------------
# dp50 blow volume
#
# cut_index =  14
# blow_volume =  0.0003772769684782676
# null_volume =  5.934687834281854e-05
# final blow_volume =  0.00031793009013544903
# --------------------------------
# dp51 blow volume
#
# cut_index =  12
# blow_volume =  0.0003759026868529521
# null_volume =  4.6118723772489514e-05
# final blow_volume =  0.0003297839630804626
# --------------------------------
# dp52 blow volume
#
# cut_index =  18
# blow_volume =  0.00037714164526186407
# null_volume =  5.68692575892977e-05
# final blow_volume =  0.0003202723876725664
# --------------------------------
# dp53 blow volume
#
# cut_index =  13
# blow_volume =  0.0003773268825226017
# null_volume =  5.464482213389511e-05
# final blow_volume =  0.0003226820603887066
# --------------------------------
# dp54 blow volume
#
# cut_index =  16
# blow_volume =  0.00037648766687539497
# null_volume =  5.604448757313441e-05
# final blow_volume =  0.00032044317930226055
# --------------------------------
# dp55 blow volume
#
# cut_index =  14
# blow_volume =  0.00037582590456282345
# null_volume =  5.4991120993960045e-05
# final blow_volume =  0.0003208347835688634
# --------------------------------
# dp56 blow volume
#
# cut_index =  17
# blow_volume =  0.0003773277137253421
# null_volume =  5.4093084561888584e-05
# final blow_volume =  0.00032323462916345353
# --------------------------------
# dp57 blow volume
#
# cut_index =  13
# blow_volume =  0.0003770235684542924
# null_volume =  5.921073982062122e-05
# final blow_volume =  0.00031781282863367117
# --------------------------------
# dp58 blow volume
#
# cut_index =  16
# blow_volume =  0.00037610113347865776
# null_volume =  5.294050839028692e-05
# final blow_volume =  0.00032316062508837084
# --------------------------------
# dp59 blow volume
#
# cut_index =  12
# blow_volume =  0.00037724847558223153
# null_volume =  5.6174061988292925e-05
# final blow_volume =  0.0003210744135939386
# --------------------------------
# dp60 blow volume
#
# cut_index =  12
# blow_volume =  0.00037800708008280874
# null_volume =  6.0866361328493035e-05
# final blow_volume =  0.0003171407187543157
# --------------------------------
# dp61 blow volume
#
# cut_index =  13
# blow_volume =  0.0003770259341577037
# null_volume =  5.913824687716303e-05
# final blow_volume =  0.0003178876872805406
# --------------------------------
# dp62 blow volume
#
# cut_index =  15
# blow_volume =  0.00037686248882952465
# null_volume =  5.8898513216059634e-05
# final blow_volume =  0.000317963975613465
# --------------------------------
# dp63 blow volume
#
# cut_index =  14
# blow_volume =  0.0003772340956764231
# null_volume =  6.053795084585252e-05
# final blow_volume =  0.0003166961448305706
# --------------------------------
# dp64 blow volume
#
# cut_index =  17
# blow_volume =  0.0003766663818990435
# null_volume =  5.383852808370339e-05
# final blow_volume =  0.0003228278538153401
# --------------------------------
# dp65 blow volume
#
# cut_index =  14
# blow_volume =  0.00037808095090649703
# null_volume =  6.173131782133362e-05
# final blow_volume =  0.0003163496330851634
# --------------------------------
# dp66 blow volume
#
# cut_index =  14
# blow_volume =  0.00037769361921075956
# null_volume =  6.057680355562816e-05
# final blow_volume =  0.0003171168156551314
# --------------------------------
# dp67 blow volume
#
# cut_index =  13
# blow_volume =  0.0003766410849806426
# null_volume =  5.3492289978284435e-05
# final blow_volume =  0.00032314879500235815
# --------------------------------
# dp68 blow volume
#
# cut_index =  14
# blow_volume =  0.00037664769127113487
# null_volume =  5.4232053883888994e-05
# final blow_volume =  0.0003224156373872459
# --------------------------------
# dp69 blow volume
#
# cut_index =  14
# blow_volume =  0.00037698886235009864
# null_volume =  5.8076404743337686e-05
# final blow_volume =  0.00031891245760676094
# --------------------------------
# dp70 blow volume
#
# cut_index =  15
# blow_volume =  0.0003767990757768535
# null_volume =  5.729343460411403e-05
# final blow_volume =  0.0003195056411727395
# --------------------------------
# dp71 blow volume
#
# cut_index =  15
# blow_volume =  0.0003770165716032693
# null_volume =  5.322642513480873e-05
# final blow_volume =  0.0003237901464684606
# --------------------------------
# dp72 blow volume
#
# cut_index =  15
# blow_volume =  0.0003776040936324528
# null_volume =  5.8932599923130336e-05
# final blow_volume =  0.0003186714937093224
# --------------------------------
# dp73 blow volume
#
# cut_index =  14
# blow_volume =  0.0003770957710688148
# null_volume =  5.89500027442595e-05
# final blow_volume =  0.0003181457683245553
# --------------------------------
# dp74 blow volume
#
# cut_index =  15
# blow_volume =  0.0003769924284877455
# null_volume =  5.4531568754327086e-05
# final blow_volume =  0.0003224608597334184
# --------------------------------
# dp75 blow volume
#
# cut_index =  13
# blow_volume =  0.0003774225917183795
# null_volume =  5.552707121349676e-05
# final blow_volume =  0.00032189552050488273
# --------------------------------
# dp76 blow volume
#
# cut_index =  15
# blow_volume =  0.0003769287501063139
# null_volume =  5.7321776709165364e-05
# final blow_volume =  0.00031960697339714853
# --------------------------------
# dp77 blow volume
#
# cut_index =  13
# blow_volume =  0.0003772836887783323
# null_volume =  5.675787445300171e-05
# final blow_volume =  0.0003205258143253306
# --------------------------------
# dp78 blow volume
#
# cut_index =  14
# blow_volume =  0.0003776858004401185
# null_volume =  5.922691587110433e-05
# final blow_volume =  0.00031845888456901415
# --------------------------------
# dp79 blow volume
#
# cut_index =  15
# blow_volume =  0.0003778410768074884
# null_volume =  5.969268955744989e-05
# final blow_volume =  0.0003181483872500385
# --------------------------------
# dp80 blow volume
#
# cut_index =  16
# blow_volume =  0.0003771900503106615
# null_volume =  5.499605539485965e-05
# final blow_volume =  0.0003221939949158019
# --------------------------------
# dp81 blow volume
#
# cut_index =  7
# blow_volume =  0.0003797590783547315
# null_volume =  2.3298424549330434e-06
# final blow_volume =  0.0003774292358997985
# --------------------------------
# dp82 blow volume
#
# cut_index =  17
# blow_volume =  0.0003772367201515792
# null_volume =  5.395449591533109e-05
# final blow_volume =  0.0003232822242362481
# --------------------------------
# dp83 blow volume
#
# cut_index =  15
# blow_volume =  0.0003772111391415193
# null_volume =  5.507706236115247e-05
# final blow_volume =  0.0003221340767803668
# --------------------------------
# dp84 blow volume
#
# cut_index =  16
# blow_volume =  0.0003772368744508587
# null_volume =  5.547025434073724e-05
# final blow_volume =  0.0003217666201101215
# --------------------------------
# dp85 blow volume
#
# cut_index =  13
# blow_volume =  0.00037738611790183387
# null_volume =  5.707767544302819e-05
# final blow_volume =  0.00032030844245880565
# --------------------------------
# dp86 blow volume
#
# cut_index =  14
# blow_volume =  0.0003778268607145489
# null_volume =  6.174238796280905e-05
# final blow_volume =  0.00031608447275173983
# --------------------------------
# dp87 blow volume
#
# cut_index =  13
# blow_volume =  0.000376978068790192
# null_volume =  5.4870543133037726e-05
# final blow_volume =  0.0003221075256571543
# --------------------------------
# dp88 blow volume
#
# cut_index =  17
# blow_volume =  0.00037693423961128203
# null_volume =  5.541518763722777e-05
# final blow_volume =  0.0003215190519740543
# --------------------------------
# dp89 blow volume
#
# cut_index =  12
# blow_volume =  0.00037737447319410037
# null_volume =  5.6610978398201786e-05
# final blow_volume =  0.0003207634947958986
# --------------------------------
# dp90 blow volume
#
# cut_index =  15
# blow_volume =  0.0003776452959623282
# null_volume =  5.8683349531074007e-05
# final blow_volume =  0.00031896194643125415
# --------------------------------
# dp91 blow volume
#
# cut_index =  13
# blow_volume =  0.0003773118347942455
# null_volume =  5.407470116940921e-05
# final blow_volume =  0.00032323713362483633
# --------------------------------
# dp92 blow volume
#
# cut_index =  17
# blow_volume =  0.00037733989411811844
# null_volume =  5.747621152694344e-05
# final blow_volume =  0.00031986368259117497
# --------------------------------
# dp93 blow volume
#
# cut_index =  14
# blow_volume =  0.00037716287412900557
# null_volume =  5.472021635631886e-05
# final blow_volume =  0.00032244265777268673
# --------------------------------
# dp94 blow volume
#
# cut_index =  14
# blow_volume =  0.00037751575228928944
# null_volume =  5.781301094607435e-05
# final blow_volume =  0.00031970274134321506
# --------------------------------
# dp95 blow volume
#
# cut_index =  15
# blow_volume =  0.000377687113872814
# null_volume =  5.7120321658181815e-05
# final blow_volume =  0.00032056679221463216
# --------------------------------
# dp96 blow volume
#
# cut_index =  13
# blow_volume =  0.0003769772811128163
# null_volume =  5.305995555904615e-05
# final blow_volume =  0.00032391732555377015
# --------------------------------
# dp97 blow volume
#
# cut_index =  17
# blow_volume =  0.0003768802548013816
# null_volume =  5.5741003811736375e-05
# final blow_volume =  0.0003211392509896452
# --------------------------------
# dp98 blow volume
#
# cut_index =  13
# blow_volume =  0.00037776592337866434
# null_volume =  5.692383181657414e-05
# final blow_volume =  0.0003208420915620902
# --------------------------------
# dp99 blow volume
#
# cut_index =  12
# blow_volume =  0.00037758633779948805
# null_volume =  6.002926070244814e-05
# final blow_volume =  0.0003175570770970399
# --------------------------------
# dp100 blow volume
#
# cut_index =  18
# blow_volume =  0.0003773188265194055
# null_volume =  5.85852913825532e-05
# final blow_volume =  0.00031873353513685234
# --------------------------------

# %%
blow_volume_factor = []
for j in range(100):
    exec("temp_blow_xy = dp%d_blow_xy"%(j+1))
    blow_volume = 0
    for i in range(temp_blow_xy.shape[0]-1):
        height = np.abs(temp_blow_xy.iloc[i+1,1]-temp_blow_xy.iloc[i,1])
        width = np.abs(temp_blow_xy.iloc[i+1,0]+temp_blow_xy.iloc[i,0])/2
        
        bottom_area = np.pi* np.square(width)
        
        volume_ = height * bottom_area
        
        blow_volume = blow_volume + volume_
    blow_volume_factor = np.append(blow_volume_factor,blow_volume)
    
blow_volume_factor
# Out:
# array([0.00038051, 0.00037928, 0.00037962, 0.00037973, 0.00038041,
#        0.00038074, 0.00038109, 0.00038111, 0.000381  , 0.0003803 ,
#        0.00038071, 0.00037989, 0.00037976, 0.00037818, 0.00038041,
#        0.00038008, 0.00038021, 0.00037926, 0.00038049, 0.00037937,
#        0.00038049, 0.00038065, 0.00037977, 0.00037947, 0.00037924,
#        0.00037994, 0.00038044, 0.00038062, 0.00038061, 0.00038137,
#        0.00038051, 0.00037888, 0.00037997, 0.00038061, 0.00038128,
#        0.0003804 , 0.00038137, 0.00038121, 0.00038068, 0.00038069,
#        0.00038038, 0.00037997, 0.00038016, 0.00037971, 0.00038007,
#        0.00037999, 0.00037975, 0.00038091, 0.00038041, 0.00038077,
#        0.00037841, 0.00038048, 0.00038046, 0.00037977, 0.00037901,
#        0.00038043, 0.00038055, 0.00037914, 0.00038051, 0.00038161,
#        0.0003805 , 0.00038032, 0.00038083, 0.00037976, 0.00038174,
#        0.00038127, 0.00037971, 0.00037973, 0.00038042, 0.00038013,
#        0.00038003, 0.00038106, 0.00038057, 0.00038015, 0.00038059,
#        0.00038027, 0.0003806 , 0.00038118, 0.00038136, 0.00038039,
#        0.0003798 , 0.00038033, 0.0003804 , 0.00038045, 0.00038068,
#        0.0003815 , 0.00038009, 0.00038014, 0.00038072, 0.00038108,
#        0.00038038, 0.00038074, 0.00038032, 0.0003809 , 0.00038101,
#        0.00037996, 0.00038011, 0.00038105, 0.00038115, 0.00038079])

# %% [markdown]
# ### blow 가로세로 종횡비 = y_max / x_max

# %%
blow_xyratio_factor = []
for j in range(100):
    exec("temp_blow_xy = dp%d_blow_xy"%(j+1))
    x_max = np.max(np.abs(temp_blow_xy.iloc[:,0]))
    y_max = np.max(np.abs(temp_blow_xy.iloc[:,1]))
    xyratio = y_max/x_max
    blow_xyratio_factor = np.append(blow_xyratio_factor,xyratio)
blow_xyratio_factor
# Out:
# array([1.99489022, 1.99341444, 2.00116539, 1.99850044, 2.00290619,
#        2.00119517, 1.99915885, 2.00974523, 2.00825324, 2.00274996,
#        2.00553409, 1.99896706, 2.00011673, 1.98767518, 2.00090513,
#        1.9954808 , 1.99435895, 1.99691102, 2.00673779, 1.99754119,
#        1.99849014, 2.00017529, 2.00464587, 1.99809275, 1.99495753,
#        2.00378671, 2.00446783, 2.00193683, 2.00661953, 2.0052876 ,
#        1.99935295, 1.99055554, 1.99409972, 2.00268865, 1.99987037,
#        2.00414907, 1.99820986, 2.00671163, 2.0042684 , 2.00452926,
#        1.99473189, 2.00039697, 2.00097519, 2.0011201 , 1.99862777,
#        2.00235569, 1.9943004 , 2.00087169, 1.99842755, 2.00581144,
#        1.98840163, 2.00330737, 1.99869273, 1.99929957, 2.00157116,
#        1.99775147, 2.00613998, 2.00032079, 2.00089742, 2.00486169,
#        2.0050729 , 2.00388572, 2.00664013, 1.99639109, 2.00521587,
#        2.0022152 , 2.00007262, 1.99712483, 2.00307854, 1.99768902,
#        1.99520606, 2.00105961, 2.00150522, 1.9995849 , 1.99704284,
#        2.0032112 , 2.00085026, 2.00202721, 2.00114189, 1.99778519,
#        1.99968672, 1.99807702, 2.00104076, 1.99932659, 2.00087191,
#        2.00358696, 2.00157656, 2.00299895, 2.00066267, 2.00379337,
#        1.99638053, 2.00053512, 1.99902828, 2.00041062, 1.99661105,
#        1.99989805, 2.00042355, 1.99828009, 2.00475455, 2.00396205])

# %% [markdown]
# ## stretch_1_factor = y_blow / y_pre

# %%
stretch_1_factor = []
for j in range(100):
    exec("temp_preform_xy = dp%d_preform_xy"%(j+1))
    exec("temp_blow_xy = dp%d_blow_xy"%(j+1))
    y_pre = np.abs(temp_preform_xy.iloc[0,1]-temp_preform_xy.iloc[-1,1])
    y_blow = np.abs(temp_blow_xy.iloc[0,1]-temp_blow_xy.iloc[-1,1])
    stretch_1 = y_blow/y_pre
    stretch_1_factor = np.append(stretch_1_factor,stretch_1)
    
stretch_1_factor
# Out:
# array([1.90909836, 1.90935731, 1.90884631, 1.90919358, 1.90903349,
#        1.90922484, 1.90912089, 1.90907183, 1.90917595, 1.90920558,
#        1.90941365, 1.90928335, 1.90947543, 1.90895262, 1.90915215,
#        1.90910399, 1.90931134, 1.90915251, 1.90949033, 1.90924864,
#        1.90914343, 1.90924501, 1.9091427 , 1.90937857, 1.90905892,
#        1.90903021, 1.9091129 , 1.90919685, 1.9090542 , 1.90919122,
#        1.90902603, 1.90907873, 1.90910635, 1.90903567, 1.90926954,
#        1.90930389, 1.90896625, 1.90917759, 1.90924573, 1.9090631 ,
#        1.90897788, 1.90930189, 1.90937603, 1.90933096, 1.90891391,
#        1.90918031, 1.90938003, 1.90928753, 1.90898042, 1.90907183,
#        1.90926627, 1.90947997, 1.90898315, 1.90941855, 1.90921811,
#        1.90932188, 1.90917995, 1.90953286, 1.90925319, 1.90892881,
#        1.90908328, 1.90915342, 1.90928535, 1.9093584 , 1.90903421,
#        1.90915869, 1.90894699, 1.90914888, 1.90920721, 1.90915306,
#        1.90929008, 1.90898751, 1.90921193, 1.90933078, 1.90904948,
#        1.90899896, 1.90906038, 1.90897915, 1.90916614, 1.90920449,
#        1.9095592 , 1.90915233, 1.90915924, 1.90937767, 1.90895444,
#        1.90911526, 1.90900968, 1.9089737 , 1.90901077, 1.90904257,
#        1.90928317, 1.90941183, 1.90895225, 1.90904584, 1.90904766,
#        1.9092083 , 1.90909909, 1.90891282, 1.9089846 , 1.90923538])

# %% [markdown]
# ### stretch_2_factor = L_blow / L_pre

# %%
stretch_2_factor = blow_length_factor / preform_length_factor
stretch_2_factor
# Out:
# array([2.15498435, 2.15575501, 2.15627265, 2.1544272 , 2.15489239,
#        2.15540526, 2.15564587, 2.15696914, 2.1574315 , 2.15584931,
#        2.15780023, 2.15573976, 2.15400339, 2.15290601, 2.15534273,
#        2.15382161, 2.15421142, 2.15497049, 2.15615364, 2.15516943,
#        2.15543278, 2.15597169, 2.155508  , 2.15290116, 2.15416683,
#        2.15531483, 2.15605759, 2.15501194, 2.1559177 , 2.15640677,
#        2.15732164, 2.15499317, 2.15503371, 2.15647969, 2.15764859,
#        2.15602791, 2.15845094, 2.15760941, 2.15616007, 2.15662832,
#        2.15651303, 2.15341512, 2.15543964, 2.15492121, 2.15722424,
#        2.15544511, 2.1549016 , 2.15591865, 2.15663671, 2.15865785,
#        2.15353173, 2.15742399, 2.158202  , 2.15448925, 2.15402101,
#        2.15710668, 2.15597881, 2.15442001, 2.15838356, 2.15808786,
#        2.1571305 , 2.15652206, 2.15690235, 2.15471939, 2.15959525,
#        2.15877761, 2.15709037, 2.15626838, 2.15647966, 2.15562656,
#        2.15657505, 2.15818111, 2.15653944, 2.15576824, 2.15877375,
#        2.15629759, 2.15732038, 2.15792952, 2.15840665, 2.15484577,
#        2.15459846, 2.15712566, 2.15805119, 2.15653981, 2.1591278 ,
#        2.15835376, 2.15793705, 2.15750885, 2.15810244, 2.15922254,
#        2.15794147, 2.15619058, 2.15636212, 2.15865958, 2.15798447,
#        2.15845707, 2.15700198, 2.15980613, 2.15773343, 2.15771458])

# %% [markdown]
# ### stretch_3_factor = A_blow / A_pre

# %%
stretch_3_factor = blow_area_factor / preform_area_factor
stretch_3_factor
# Out:
# array([3.36872628, 3.36499854, 3.36567037, 3.36595667, 3.36420846,
#        3.36641415, 3.36873683, 3.36548565, 3.36586575, 3.36440982,
#        3.36596618, 3.36610798, 3.36325935, 3.36285086, 3.36523513,
#        3.36617704, 3.36750759, 3.36351382, 3.36670382, 3.36487385,
#        3.36730576, 3.36748602, 3.36347837, 3.36364623, 3.36497923,
#        3.36565038, 3.36449097, 3.36696578, 3.36645026, 3.36806688,
#        3.36769815, 3.36656286, 3.36698085, 3.36668459, 3.36791561,
#        3.36549974, 3.37033729, 3.36763207, 3.36626553, 3.36583375,
#        3.36729167, 3.36419127, 3.36568966, 3.3646752 , 3.36787634,
#        3.3642654 , 3.36692205, 3.36700299, 3.36720734, 3.36694542,
#        3.36372037, 3.36771629, 3.36870198, 3.36411432, 3.36120068,
#        3.36904219, 3.36495479, 3.36364388, 3.36742742, 3.36934803,
#        3.36579043, 3.36504996, 3.36623376, 3.36613888, 3.3698458 ,
#        3.36858042, 3.36551878, 3.36582107, 3.36561351, 3.36527329,
#        3.36810149, 3.3687335 , 3.36617517, 3.36692135, 3.36900138,
#        3.36600646, 3.36751576, 3.36879323, 3.36937512, 3.3677586 ,
#        3.48057587, 3.36864286, 3.36816775, 3.36821983, 3.3683423 ,
#        3.36863095, 3.3672425 , 3.36702209, 3.36728226, 3.36891104,
#        3.36896774, 3.36786607, 3.36768957, 3.36816242, 3.36944099,
#        3.36771703, 3.36677378, 3.37017163, 3.36771151, 3.36766955])

# %% [markdown]
# ### stretch_4_factor = V_blow / V_pre

# %%
stretch_4_factor = blow_volume_factor / preform_volume_factor
stretch_4_factor
# Out:
# array([5.58701037, 5.56897354, 5.57400406, 5.57557156, 5.58553932,
#        5.59036425, 5.59551983, 5.59575234, 5.59417761, 5.58392242,
#        5.59001528, 5.57785213, 5.57596062, 5.55286863, 5.58547425,
#        5.58063675, 5.58256769, 5.56872599, 5.58665526, 5.57026881,
#        5.58666228, 5.58904919, 5.57620091, 5.5716881 , 5.56837999,
#        5.57868898, 5.58600508, 5.5886149 , 5.58847579, 5.59960971,
#        5.58702468, 5.56310542, 5.5790931 , 5.58847514, 5.59828315,
#        5.58541112, 5.59961359, 5.59732957, 5.58956323, 5.58965835,
#        5.58511249, 5.57905542, 5.5818179 , 5.57530877, 5.5805825 ,
#        5.57933391, 5.57581798, 5.59288731, 5.585573  , 5.59084003,
#        5.55615412, 5.58658838, 5.58624622, 5.57613829, 5.56491679,
#        5.58589791, 5.58752799, 5.56682041, 5.58700588, 5.6031182 ,
#        5.58687707, 5.5841952 , 5.5916434 , 5.57593038, 5.60513745,
#        5.59812367, 5.57527809, 5.57561611, 5.58572878, 5.58142762,
#        5.57997446, 5.59504318, 5.58784854, 5.58168415, 5.58818276,
#        5.58342843, 5.58836819, 5.5968581 , 5.59951826, 5.58525631,
#        5.57655031, 5.58440681, 5.58538144, 5.58617419, 5.5894369 ,
#        5.60147772, 5.58080197, 5.58159164, 5.59004823, 5.59541311,
#        5.5850371 , 5.5903133 , 5.58424214, 5.59279408, 5.59434543,
#        5.57893219, 5.58116315, 5.59499125, 5.5963368 , 5.59114811])

# %% [markdown]
# ### blow 대각길이 / 옆면길이 / 바닥길이

# %%
# 앞뒤 자르기 
front_cut_list = []
back_cut_list  = []
for k in range (100):
    s = "temp_blow_xy = dp%d_blow_xy"%(k+1) ; exec(s)
    
    for i in range (temp_blow_xy.shape[0]):
        if -1<(temp_blow_xy.iloc[i,0]- temp_blow_xy.iloc[i+1,0])/(temp_blow_xy.iloc[i,1]- temp_blow_xy.iloc[i+1,1])<1:
            front_cut_index = i
            front_cut_list = np.append(front_cut_list ,front_cut_index+1)
            print(s)
            print("front cut index : ",front_cut_index+1)
            break

    temp_blow_xy_reverse = temp_blow_xy[::-1]

    for j in range (1,temp_blow_xy_reverse.shape[0]):
        if -1<(temp_blow_xy_reverse.iloc[j,0]- temp_blow_xy_reverse.iloc[j+1,0])/(temp_blow_xy_reverse.iloc[j,1]- temp_blow_xy_reverse.iloc[j+1,1])<1:
            back_cut_index = j
            back_cut_list = np.append(back_cut_list,back_cut_index+1)
            print("back cut index : ",back_cut_index+1)
            print('\t')
            break
# Out:
# temp_blow_xy = dp1_blow_xy
# front cut index :  15
# back cut index :  5
#
# temp_blow_xy = dp2_blow_xy
# front cut index :  14
# back cut index :  4
#
# temp_blow_xy = dp3_blow_xy
# front cut index :  15
# back cut index :  5
#
# temp_blow_xy = dp4_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp5_blow_xy
# front cut index :  16
# back cut index :  4
#
# temp_blow_xy = dp6_blow_xy
# front cut index :  16
# back cut index :  4
#
# temp_blow_xy = dp7_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp8_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp9_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp10_blow_xy
# front cut index :  16
# back cut index :  4
#
# temp_blow_xy = dp11_blow_xy
# front cut index :  16
# back cut index :  4
#
# temp_blow_xy = dp12_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp13_blow_xy
# front cut index :  19
# back cut index :  4
#
# temp_blow_xy = dp14_blow_xy
# front cut index :  15
# back cut index :  4
#
# temp_blow_xy = dp15_blow_xy
# front cut index :  17
# back cut index :  4
#
# temp_blow_xy = dp16_blow_xy
# front cut index :  16
# back cut index :  4
#
# temp_blow_xy = dp17_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp18_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp19_blow_xy
# front cut index :  22
# back cut index :  5
#
# temp_blow_xy = dp20_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp21_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp22_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp23_blow_xy
# front cut index :  15
# back cut index :  4
#
# temp_blow_xy = dp24_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp25_blow_xy
# front cut index :  15
# back cut index :  5
#
# temp_blow_xy = dp26_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp27_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp28_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp29_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp30_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp31_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp32_blow_xy
# front cut index :  15
# back cut index :  5
#
# temp_blow_xy = dp33_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp34_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp35_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp36_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp37_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp38_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp39_blow_xy
# front cut index :  17
# back cut index :  4
#
# temp_blow_xy = dp40_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp41_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp42_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp43_blow_xy
# front cut index :  19
# back cut index :  4
#
# temp_blow_xy = dp44_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp45_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp46_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp47_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp48_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp49_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp50_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp51_blow_xy
# front cut index :  15
# back cut index :  5
#
# temp_blow_xy = dp52_blow_xy
# front cut index :  22
# back cut index :  5
#
# temp_blow_xy = dp53_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp54_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp55_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp56_blow_xy
# front cut index :  21
# back cut index :  5
#
# temp_blow_xy = dp57_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp58_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp59_blow_xy
# front cut index :  15
# back cut index :  5
#
# temp_blow_xy = dp60_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp61_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp62_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp63_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp64_blow_xy
# front cut index :  21
# back cut index :  5
#
# temp_blow_xy = dp65_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp66_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp67_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp68_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp69_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp70_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp71_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp72_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp73_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp74_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp75_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp76_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp77_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp78_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp79_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp80_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp81_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp82_blow_xy
# front cut index :  22
# back cut index :  5
#
# temp_blow_xy = dp83_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp84_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp85_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp86_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp87_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp88_blow_xy
# front cut index :  21
# back cut index :  5
#
# temp_blow_xy = dp89_blow_xy
# front cut index :  15
# back cut index :  5
#
# temp_blow_xy = dp90_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp91_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp92_blow_xy
# front cut index :  20
# back cut index :  5
#
# temp_blow_xy = dp93_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp94_blow_xy
# front cut index :  18
# back cut index :  5
#
# temp_blow_xy = dp95_blow_xy
# front cut index :  19
# back cut index :  5
#
# temp_blow_xy = dp96_blow_xy
# front cut index :  17
# back cut index :  6
#
# temp_blow_xy = dp97_blow_xy
# front cut index :  21
# back cut index :  5
#
# temp_blow_xy = dp98_blow_xy
# front cut index :  17
# back cut index :  5
#
# temp_blow_xy = dp99_blow_xy
# front cut index :  16
# back cut index :  5
#
# temp_blow_xy = dp100_blow_xy
# front cut index :  22
# back cut index :  5

# %%
blow_bottom_length_factor = []
blow_top_length_factor    = []
for k in range (100):
    #바닥부분 길이
    exec("temp_bottom_data = dp%d_blow_xy.iloc[:int(front_cut_list[k]),:]"%(k+1))
    
    temp_bottom_length = 0
    for i in range(temp_bottom_data.shape[0]-1):
        a = np.square(temp_bottom_data.iloc[i,0]-temp_bottom_data.iloc[i+1,0])
        b = np.square(temp_bottom_data.iloc[i,1]-temp_bottom_data.iloc[i+1,1])
        temp_bottom_length = temp_bottom_length + np.sqrt(a+b)
    blow_bottom_length_factor = np.append(blow_bottom_length_factor, temp_bottom_length)

    exec("dp%d_blow_xy_reverse = dp%d_blow_xy[::-1]"%(k+1,k+1))
    exec("temp_top_data = dp%d_blow_xy_reverse.iloc[:int(back_cut_list[k]),:]"%(k+1))
    temp_top_length = 0
    for j in range(temp_top_data.shape[0]-1):
        a = np.square(temp_top_data.iloc[j,0]-temp_top_data.iloc[j+1,0])
        b = np.square(temp_top_data.iloc[j,1]-temp_top_data.iloc[j+1,1])
        temp_top_length = temp_top_length + np.sqrt(a+b)
    blow_top_length_factor = np.append(blow_top_length_factor, temp_top_length)
    
    
blow_bottom_length_factor,blow_top_length_factor
# Out:
# (array([0.03580764, 0.03478017, 0.03687313, 0.03581927, 0.03773442,
#         0.03596864, 0.0348066 , 0.03734339, 0.03920592, 0.03451193,
#         0.03512624, 0.03626789, 0.0367531 , 0.0368822 , 0.03755374,
#         0.03626112, 0.03591348, 0.03513613, 0.0354967 , 0.03502185,
#         0.03659111, 0.03695789, 0.03517752, 0.03400113, 0.03654604,
#         0.0369748 , 0.0370587 , 0.03371935, 0.03414267, 0.03582072,
#         0.03545913, 0.03786107, 0.03397289, 0.03774761, 0.03781886,
#         0.03495355, 0.03603252, 0.03500742, 0.03567528, 0.03646839,
#        0.07701886, 0.07881312, 0.07568436, 0.07301837, 0.07760554,
#        0.07577759, 0.07553771, 0.07629188, 0.07505197, 0.07506697,
#        0.07509333, 0.07845778, 0.076574  , 0.07461998, 0.07752693,
#        0.07667151, 0.07548137, 0.0767532 , 0.07655411, 0.07646009,
#        0.07513651, 0.07430977, 0.07471013, 0.07733819, 0.07778776,
#        0.07529055, 0.07784518, 0.07381119, 0.07513876, 0.08066561,
#        0.07470143, 0.07901626, 0.075268  , 0.07814427, 0.07538141,
#        0.07633329, 0.07592522, 0.07821309, 0.07991975, 0.07577983,
#        0.07588469, 0.07740341, 0.07682717, 0.07681528, 0.07850182,
#        0.07724777, 0.07863234, 0.07645244, 0.07764437, 0.07850872,
#        0.07776885, 0.07889608, 0.07800929, 0.07541983, 0.07897696,
#        0.07338729, 0.07808523, 0.07949752, 0.07690248, 0.07679837])

# %% [markdown]
# ## 형상인자 table 만들기

# %%
testcase[-1]
# Out:
# '5'

# %%
factor_table = pd.DataFrame((np.zeros((100,16))),columns = ["case","L_pre","A_pre","V_pre","xyratio_pre",
                                            "L_blow","A_blow","V_blow","xyratio_blow",
                                            "y_blow/y_pre","L_blow/L_pre","A_blow/A_pre","V_blow/V_pre",
                                            "bot_len","side_len","top_len"])

# %%
for i in range(100):
    exec("factor_table.iloc[i,0] = 't%s_dp%d'"%(testcase[-1],i+1))
    factor_table.iloc[:,1] = preform_length_factor
    factor_table.iloc[:,2] = preform_area_factor
    factor_table.iloc[:,3] = preform_volume_factor
    factor_table.iloc[:,4] = preform_xyratio_factor

    factor_table.iloc[:,5] = blow_length_factor
    factor_table.iloc[:,6] = blow_area_factor
    factor_table.iloc[:,7] = blow_volume_factor
    factor_table.iloc[:,8] = blow_xyratio_factor

    factor_table.iloc[:,9] = stretch_1_factor
    factor_table.iloc[:,10] = stretch_2_factor
    factor_table.iloc[:,11] = stretch_3_factor
    factor_table.iloc[:,12] = stretch_4_factor

    factor_table.iloc[:,13] = blow_bottom_length_factor
    factor_table.iloc[:,14] = blow_side_length_factor
    factor_table.iloc[:,15] = blow_top_length_factor

# %%
pd.set_option("display.max_rows",10)
factor_table
# Out:
#         case     L_pre     A_pre     V_pre  xyratio_pre    L_blow    A_blow  \
# 0     t5_dp1  0.055841  0.000912  0.000068     1.254085  0.120336  0.003073
# 1     t5_dp2  0.055841  0.000912  0.000068     1.254085  0.120379  0.003069
# 2     t5_dp3  0.055841  0.000912  0.000068     1.254085  0.120408  0.003070
# 3     t5_dp4  0.055841  0.000912  0.000068     1.254085  0.120305  0.003070
# 4     t5_dp5  0.055841  0.000912  0.000068     1.254085  0.120331  0.003069
# ..       ...       ...       ...       ...          ...       ...       ...
# 95   t5_dp96  0.055841  0.000912  0.000068     1.254085  0.120530  0.003072
# 96   t5_dp97  0.055841  0.000912  0.000068     1.254085  0.120449  0.003071
# 97   t5_dp98  0.055841  0.000912  0.000068     1.254085  0.120605  0.003074
# 98   t5_dp99  0.055841  0.000912  0.000068     1.254085  0.120490  0.003072
# 99  t5_dp100  0.055841  0.000912  0.000068     1.254085  0.120489  0.003072
#
#       V_blow  xyratio_blow  y_blow/y_pre  L_blow/L_pre  A_blow/A_pre  \
# 
# 97      5.594991  0.034115  0.079498  0.006993
# 98      5.596337  0.036093  0.076902  0.007494
# 99      5.591148  0.036700  0.076798  0.006990
#
# [100 rows x 16 columns]

# %%
total_xy_factor_table = pd.DataFrame(np.zeros((500,16)),columns = ["case","L_pre","A_pre","V_pre","xyratio_pre",
                                            "L_blow","A_blow","V_blow","xyratio_blow",
                                            "y_blow/y_pre","L_blow/L_pre","A_blow/A_pre","V_blow/V_pre",
                                            "bot_len","side_len","top_len"])
for i in range(5):
    exec("temp_xy_factor_table = test%d_xy_factor_table"%(i+1))
    
    for j in range (100):
        total_xy_factor_table.iloc[100*i+j,:] = temp_xy_factor_table.iloc[j,:]

# %%
pd.set_option("display.max_rows",50)
total_xy_factor_table
# Out:
#          case     L_pre     A_pre     V_pre  xyratio_pre    L_blow    A_blow  \
# 0      t1_dp1  0.104965  0.003375  0.000510     1.297975  0.297487  0.014325
# 1      t1_dp2  0.104965  0.003375  0.000510     1.297975  0.297424  0.014320
# 2      t1_dp3  0.104965  0.003375  0.000510     1.297975  0.298458  0.014331
# 3      t1_dp4  0.104965  0.003375  0.000510     1.297975  0.297550  0.014326
# 4      t1_dp5  0.104965  0.003375  0.000510     1.297975  0.297495  0.014327
# ..        ...       ...       ...       ...          ...       ...       ...
# 495   t5_dp96  0.055841  0.000912  0.000068     1.254085  0.120530  0.003072
# 496   t5_dp97  0.055841  0.000912  0.000068     1.254085  0.120449  0.003071
# 497   t5_dp98  0.055841  0.000912  0.000068     1.254085  0.120605  0.003074
# 498   t5_dp99  0.055841  0.000912  0.000068     1.254085  0.120490  0.003072
# 499  t5_dp100  0.055841  0.000912  0.000068     1.254085  0.120489  0.003072
#
#        V_blow  xyratio_blow  y_blow/y_pre  L_blow/L_pre  A_blow/A_pre  \
# 0    0.002950      3.745982      2.955304      2.834158      4.244589
# 1    0.002948      3.747782      2.956612      2.833556      4.243136
# 2    0.002950      3.746032      2.952801      2.843409      4.246218
# 3    0.002952      3.751084      2.956104      2.834763      4.244731
# 4    0.002951      3.744040      2.955551      2.834237      4.245096
# ..        ...           ...           ...           ...           ...
# 495  0.000380      1.999898      1.909208      2.158457      3.367717
# 496  0.000380      2.000424      1.909099      2.157002      3.366774
# 497  0.000381      1.998280      1.908913      2.159806      3.370172
# 498  0.000381      2.004755      1.908985      2.157733      3.367712
# 499  0.000381      2.003962      1.909235      2.157715      3.367670
#
#      V_blow/V_pre   bot_len  side_len   top_len
# 0        5.785178  0.063912  0.229694  0.003881
# 1        5.780028  0.063073  0.230426  0.003925
# 2        5.785469  0.065099  0.229499  0.003860
# 3        5.789519  0.063604  0.230037  0.003909
# 4        5.787312  0.063805  0.229800  0.003889
# ..            ...       ...       ...       ...
# 495      5.578932  0.037537  0.073387  0.009606
# 496      5.581163  0.035313  0.078085  0.007050
# 497      5.594991  0.034115  0.079498  0.006993
# 498      5.596337  0.036093  0.076902  0.007494
# 499      5.591148  0.036700  0.076798  0.006990
#
# [500 rows x 16 columns]

# %%
pd.DataFrame(total_xy_factor_table).to_csv("./factor table/total_xy_factor_table.csv")
